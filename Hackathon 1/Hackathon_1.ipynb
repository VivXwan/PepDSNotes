# %% [markdown]
# <a href="https://colab.research.google.com/github/VivXwan/PepDSNotes/blob/main/Hackathon%201/Hackathon_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df_test = pd.read_csv("test_file.csv")

# %%
df_train = pd.read_csv("train_file.csv")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (9) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_test.head()
# Out:
#                  ID  LICENSE ID  ACCOUNT NUMBER  SITE NUMBER  \
# 0  1516615-20120216     2132209          280120            1
# 1    69813-20110616     2090759           65043            1
# 2  1519227-20041116     1541990          281270            1
# 3  1922025-20100816     2041053          335243            1
# 4  1675683-20070816     1837158          283018            3
#
#                LEGAL NAME DOING BUSINESS AS NAME                   ADDRESS  \
# 0          RS HOMES I LLC         RS HOMES I LLC    350 W HUBBARD ST 3 300
# 1      CSX INTERMODAL INC         CSX INTERMODAL        2101 W 59TH ST 1ST
# 2   LOCOMIBILE  LOFTS LLC   LOCOMOBILE LOFTS LLC     1133 S WABASH AVE 1ST
# 3         ANNA F. JAMISON        ANNA F. JAMISON  13156 S FORRESTVILLE AVE
# 4  MARINCA A. COVARRUBIAS                DETAILS         4208 S ARCHER AVE
#
#       CITY STATE  ZIP CODE  WARD  PRECINCT WARD PRECINCT  POLICE DISTRICT  \
# ...

# %%
df_train.describe()
# Out:
#          LICENSE ID  ACCOUNT NUMBER   SITE NUMBER          WARD      PRECINCT  \
# count  8.589500e+04    85895.000000  85895.000000  36194.000000  29194.000000
# mean   1.751303e+06   196695.421701      2.556028     28.528927     54.632973
# std    3.358780e+05   126819.343760      8.655706     13.921710    163.174955
# min    3.079300e+04       10.000000      1.000000      1.000000      1.000000
# 25%    1.469024e+06    54615.000000      1.000000     17.000000     12.000000
# 50%    1.778754e+06   248313.000000      1.000000     30.000000     26.000000
# 75%    2.067578e+06   300243.500000      2.000000     42.000000     41.000000
# max    2.456551e+06   397444.000000    417.000000     50.000000    999.000000
#
#        POLICE DISTRICT  LICENSE CODE  LICENSE NUMBER          SSA  \
# count     31883.000000  85895.000000    8.589400e+04  9449.000000
# mean         13.529812   1111.736620    1.228151e+06    29.152080
# std           7.275874    250.020872    7.431487e+05    17.419898
# ...

# %%
df_test.describe()
# Out:
#          LICENSE ID  ACCOUNT NUMBER   SITE NUMBER      ZIP CODE          WARD  \
# count  5.723900e+04    57239.000000  57239.000000  57227.000000  56613.000000
# mean   1.867003e+06   187884.083719      4.518685  60580.682982     28.072987
# std    3.788378e+05   139139.743948     19.860738   2088.082252     14.587923
# min    9.803000e+03       10.000000      1.000000   1830.000000      1.000000
# 25%    1.553288e+06    41316.000000      1.000000  60612.000000     16.000000
# 50%    1.912282e+06   222091.000000      1.000000  60624.000000     30.000000
# 75%    2.137864e+06   312884.000000      2.000000  60641.000000     42.000000
# max    2.615886e+06   429413.000000    507.000000  98003.000000     50.000000
#
#            PRECINCT  POLICE DISTRICT  LICENSE CODE  LICENSE NUMBER  \
# count  55661.000000      55764.00000  57239.000000    5.723900e+04
# mean      27.203105         13.16369   1243.865197    1.208141e+06
# ...

# %%
df_test.info()
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57239 entries, 0 to 57238
# Data columns (total 31 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   ID                                 57239 non-null  object
#  1   LICENSE ID                         57239 non-null  int64
#  2   ACCOUNT NUMBER                     57239 non-null  int64
#  3   SITE NUMBER                        57239 non-null  int64
#  4   LEGAL NAME                         57239 non-null  object
#  5   DOING BUSINESS AS NAME             57237 non-null  object
#  6   ADDRESS                            57239 non-null  object
#  7   CITY                               57239 non-null  object
#  8   STATE                              57239 non-null  object
#  9   ZIP CODE                           57227 non-null  float64
#  10  WARD                               56613 non-null  float64
# ...

# %%
df_train['LICENSE STATUS'].unique()
# Out:
# array(['AAI', 'AAC', 'REV', 'REA', 'INQ'], dtype=object)

# %%
x = df_train.drop('LICENSE STATUS',axis = 1)
y = df_train['LICENSE STATUS']

# %%
y[y=='AAI'] = 0
y[y=='AAC'] = 1
y[y=='REA'] = 2
y[y=='REV'] = 3
y[y=='INQ'] = 4
y = y.astype('int')
y.unique()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
x.columns
# Out:
# Index(['ID', 'LICENSE ID', 'ACCOUNT NUMBER', 'SITE NUMBER', 'LEGAL NAME',
#        'DOING BUSINESS AS NAME', 'ADDRESS', 'CITY', 'STATE', 'ZIP CODE',
#        'WARD', 'PRECINCT', 'WARD PRECINCT', 'POLICE DISTRICT', 'LICENSE CODE',
#        'LICENSE DESCRIPTION', 'LICENSE NUMBER', 'APPLICATION TYPE',
#        'APPLICATION CREATED DATE', 'APPLICATION REQUIREMENTS COMPLETE',
#        'PAYMENT DATE', 'CONDITIONAL APPROVAL', 'LICENSE TERM START DATE',
#        'LICENSE TERM EXPIRATION DATE', 'LICENSE APPROVED FOR ISSUANCE',
#        'DATE ISSUED', 'LICENSE STATUS CHANGE DATE', 'SSA', 'LATITUDE',
#        'LONGITUDE', 'LOCATION'],
#       dtype='object')

# %%
import copy
nicht_raw_df = copy.deepcopy(df_train)
nicht_raw_df['LICENSE STATUS'][nicht_raw_df['LICENSE STATUS']=='AAI'] = 0
nicht_raw_df['LICENSE STATUS'][nicht_raw_df['LICENSE STATUS']=='AAC'] = 1
nicht_raw_df['LICENSE STATUS'][nicht_raw_df['LICENSE STATUS']=='REA'] = 2
nicht_raw_df['LICENSE STATUS'][nicht_raw_df['LICENSE STATUS']=='REV'] = 3
nicht_raw_df['LICENSE STATUS'][nicht_raw_df['LICENSE STATUS']=='INQ'] = 4
nicht_raw_df['LICENSE STATUS'] = nicht_raw_df['LICENSE STATUS'].astype('int')
nicht_raw_df.corr()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
nicht_raw_df['DOING BUSINESS AS NAME'].unique().size
# Out:
# 41687

# %%
nicht_raw_df.isna().sum()
# Out:
# ID                                       0
# LICENSE ID                               0
# ACCOUNT NUMBER                           0
# SITE NUMBER                              0
# LEGAL NAME                               0
# DOING BUSINESS AS NAME                   1
# ADDRESS                                  0
# CITY                                     0
# STATE                                    0
# ZIP CODE                                31
# WARD                                 49701
# PRECINCT                             56701
# WARD PRECINCT                        49700
# POLICE DISTRICT                      54012
# LICENSE CODE                             0
# LICENSE DESCRIPTION                      0
# LICENSE NUMBER                           1
# APPLICATION TYPE                         0
# APPLICATION CREATED DATE             64660
# APPLICATION REQUIREMENTS COMPLETE      214
# PAYMENT DATE                          1289
# CONDITIONAL APPROVAL                     0
# ...

# %%
for column in x.columns:
  print(column, "\t", nicht_raw_df[column].nunique())
# Out:
# ID 	 85895
# LICENSE ID 	 85895
# ACCOUNT NUMBER 	 38897
# SITE NUMBER 	 177
# LEGAL NAME 	 38744
# DOING BUSINESS AS NAME 	 41686
# ADDRESS 	 42146
# CITY 	 1223
# STATE 	 54
# ZIP CODE 	 2456
# WARD 	 50
# PRECINCT 	 76
# WARD PRECINCT 	 2383
# POLICE DISTRICT 	 28
# LICENSE CODE 	 106
# LICENSE DESCRIPTION 	 106
# LICENSE NUMBER 	 49768
# APPLICATION TYPE 	 5
# APPLICATION CREATED DATE 	 2899
# APPLICATION REQUIREMENTS COMPLETE 	 3078
# PAYMENT DATE 	 4356
# CONDITIONAL APPROVAL 	 2
# LICENSE TERM START DATE 	 2825
# LICENSE TERM EXPIRATION DATE 	 297
# LICENSE APPROVED FOR ISSUANCE 	 4223
# DATE ISSUED 	 3498
# LICENSE STATUS CHANGE DATE 	 3152
# SSA 	 53
# LATITUDE 	 21386
# LONGITUDE 	 21388
# LOCATION 	 21388

# %%
print(nicht_raw_df['LICENSE DESCRIPTION'].unique())
# Out:
# ['Limited Business License' 'Mobile Food Dispenser' 'Home Repair'
#  'Motor Vehicle Repair : Engine Only (Class II)' 'Kennels and Catteries'
#  'Hazardous Materials' 'Retail Food Establishment'
#  'Automatic Amusement Device Operator' 'Home Occupation'
#  'Peddler, food (fruits and vegtables only)' 'Music and Dance'
#  'Street Performer' 'Peddler, non-food' 'Body Piercing'
#  'Massage Therapist' 'Veterinary Hospital' 'Auctioneer' 'Broker'
#  'Residential Real Estate Developer' 'Electronic Equipment Repair'
#  'Filling Station' 'Valet Parking Operator' 'Scavenger, Private'
#  'Repossessor Class B Employee' 'Tavern'
#  'Mobile Frozen Desserts Dispenser - Non-Motorized'
#  'Peddler,food - (fruits and vegetables only) - special'
#  'Peddler, non-food, special' 'Grooming Facility' 'Package Goods'
#  'Motor Vehicle Repair; Specialty(Class I)' 'Retail Computing Center'
#  'Consumption on Premises - Incidental Activity' 'Outdoor Patio'
# ...

# %%
count = 0;
for c in nicht_raw_df['LICENSE DESCRIPTION'].unique():
  y = nicht_raw_df['LICENSE DESCRIPTION']
  y[y==c] = count
  count +=1
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
nicht_raw_df['LICENSE DESCRIPTION'] = nicht_raw_df['LICENSE DESCRIPTION'].astype('int')

# %%
nicht_raw_df.corr()
# Out:
#                      LICENSE ID  ACCOUNT NUMBER  SITE NUMBER      WARD  \
# LICENSE ID             1.000000        0.359277     0.067159  0.005275
# ACCOUNT NUMBER         0.359277        1.000000    -0.149178  0.009602
# SITE NUMBER            0.067159       -0.149178     1.000000 -0.015393
# WARD                   0.005275        0.009602    -0.015393  1.000000
# PRECINCT              -0.138596       -0.094132    -0.030387  0.053996
# POLICE DISTRICT       -0.041838       -0.029867     0.011103  0.487728
# LICENSE CODE           0.010405        0.063140     0.109418 -0.040709
# LICENSE DESCRIPTION    0.083342        0.020335     0.092295 -0.019025
# LICENSE NUMBER         0.476062        0.790922     0.042001  0.007125
# SSA                    0.034191        0.051646     0.023474 -0.147276
# LATITUDE              -0.023492       -0.012561    -0.005174  0.667520
# LONGITUDE              0.004883        0.017993     0.042247 -0.233630
# ...

# %%
count = 0;
for c in nicht_raw_df['LICENSE CODE'].unique():
  y = nicht_raw_df['LICENSE CODE']
  y[y==c] = count
  count +=1
nicht_raw_df['LICENSE CODE'] = nicht_raw_df['LICENSE CODE'].astype('int')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
nicht_raw_df.corr()
# Out:
#                      LICENSE ID  ACCOUNT NUMBER  SITE NUMBER      WARD  \
# LICENSE ID             1.000000        0.359277     0.067159  0.005275
# ACCOUNT NUMBER         0.359277        1.000000    -0.149178  0.009602
# SITE NUMBER            0.067159       -0.149178     1.000000 -0.015393
# WARD                   0.005275        0.009602    -0.015393  1.000000
# PRECINCT              -0.138596       -0.094132    -0.030387  0.053996
# POLICE DISTRICT       -0.041838       -0.029867     0.011103  0.487728
# LICENSE CODE           0.083342        0.020335     0.092295 -0.019025
# LICENSE DESCRIPTION    0.083342        0.020335     0.092295 -0.019025
# LICENSE NUMBER         0.476062        0.790922     0.042001  0.007125
# SSA                    0.034191        0.051646     0.023474 -0.147276
# LATITUDE              -0.023492       -0.012561    -0.005174  0.667520
# LONGITUDE              0.004883        0.017993     0.042247 -0.233630
# ...

# %%
count = 0;
for c in nicht_raw_df['APPLICATION TYPE'].unique():
  y = nicht_raw_df['APPLICATION TYPE']
  y[y==c] = count
  count +=1
nicht_raw_df['APPLICATION TYPE'] = nicht_raw_df['APPLICATION TYPE'].astype('int')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
nicht_raw_df.corr()
# Out:
#                      LICENSE ID  ACCOUNT NUMBER  SITE NUMBER      WARD  \
# LICENSE ID             1.000000        0.359277     0.067159  0.005275
# ACCOUNT NUMBER         0.359277        1.000000    -0.149178  0.009602
# SITE NUMBER            0.067159       -0.149178     1.000000 -0.015393
# WARD                   0.005275        0.009602    -0.015393  1.000000
# PRECINCT              -0.138596       -0.094132    -0.030387  0.053996
# POLICE DISTRICT       -0.041838       -0.029867     0.011103  0.487728
# LICENSE CODE           0.083342        0.020335     0.092295 -0.019025
# LICENSE DESCRIPTION    0.083342        0.020335     0.092295 -0.019025
# LICENSE NUMBER         0.476062        0.790922     0.042001  0.007125
# APPLICATION TYPE       0.038914        0.402903    -0.009361  0.001307
# SSA                    0.034191        0.051646     0.023474 -0.147276
# LATITUDE              -0.023492       -0.012561    -0.005174  0.667520
# ...

# %%
nicht_raw_df.hist(bins = 60, figsize = (20,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f47d99763d0>,
# ...
#       dtype=object)

# %%
pd.set_option('display.max_columns',None)

# %%
import matplotlib.pyplot as plt

# %%
nicht_raw_df[['LICENSE STATUS','SITE NUMBER']].plot(kind = 'scatter', x = 'LICENSE STATUS', y = 'SITE NUMBER', figsize = (20,10))

# %%
nicht_raw_df[nicht_raw_df['SITE NUMBER']>300]
# Out:
#                      ID  LICENSE ID  ACCOUNT NUMBER  SITE NUMBER  \
# 20550  1943333-20090507     1943333           63160          307
# 84184          2141392-     2141392           63160          417
#
#                 LEGAL NAME         DOING BUSINESS AS NAME            ADDRESS  \
# 20550  SP PLUS CORPORATION   STANDARD PARKING CORPORATION  247 E CHESTNUT ST
# 84184  SP PLUS CORPORATION  STANDARD PARKING/TALBOT HOTEL   20 E DELAWARE PL
#
#           CITY STATE ZIP CODE  WARD  PRECINCT WARD PRECINCT  POLICE DISTRICT  \
# 20550  CHICAGO    IL    60611   2.0      40.0          2-40             18.0
# 84184  CHICAGO    IL  60611.0  42.0      61.0         42-61             18.0
#
#        LICENSE CODE  LICENSE DESCRIPTION  LICENSE NUMBER  APPLICATION TYPE  \
# 20550            68                   68       1943333.0                 1
# 84184            21                   21       2141392.0                 1
#
#       APPLICATION CREATED DATE APPLICATION REQUIREMENTS COMPLETE  \
# ...

# %%
pd.DataFrame(nicht_raw_df['ZIP CODE'].value_counts())
# Out:
#          ZIP CODE
# 60804        1142
# 60647.0       925
# 60618         889
# 60639         878
# 60007         789
# ...           ...
# 90605           1
# 57108           1
# 52358           1
# 16801           1
# 61115.0         1
#
# [2456 rows x 1 columns]

# %%
nicht_raw_df['ZIP CODE'].dtype
# Out:
# dtype('O')

# %%
pd.DataFrame(nicht_raw_df['ZIP CODE'].value_counts()).plot(kind = 'bar',figsize = (20,10))

# %%
nicht_raw_df[df_train['APPLICATION TYPE'] == 'RENEW']
# Out:
#                      ID  LICENSE ID  ACCOUNT NUMBER  SITE NUMBER  \
# 0        35342-20020816     1256593           32811            1
# 1      1358463-20051116     1639294          262311           29
# 4      1141408-20080516     1896750          213785            1
# 6      1275083-20040216     1455178           36211            2
# 7      1223497-20030816     1375248          230124            1
# ...                 ...         ...             ...          ...
# 85889  1245994-20030216     1322417          204267            2
# 85890    12652-20120516     2143400            8011            1
# 85892    74137-20090116     1939358            8458            2
# 85893  2049545-20111016     2110060            2156           43
# 85894  1070196-20040216     1461628          205936            1
#
#                                      LEGAL NAME  \
# 0                                  CARMEN CAHUE
# 1                           ISLA TROPICAL, INC.
# ...

# %%
df_train['APPLICATION TYPE'].value_counts()
# Out:
# RENEW     61085
# ISSUE     23398
# C_LOC      1400
# C_CAPA        7
# C_EXPA        5
# Name: APPLICATION TYPE, dtype: int64
